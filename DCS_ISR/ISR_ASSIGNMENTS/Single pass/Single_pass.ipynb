# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os

# %%
folder = r"C:\Users\vedik\OneDrive\Desktop\DCS_ISR\ISR_ASSIGNMENTS\Single pass\clustered_files"   # Folder containing text files
documents = []
filenames = []

# %%
for file in os.listdir(folder):
    if file.endswith(".txt"):
        with open(os.path.join(folder, file), 'r', encoding='utf-8') as f:
            documents.append(f.read())
            filenames.append(file)

# %%
print("Files read:", filenames)
print("-" * 80)
# Out:
# Files read: ['file1.txt', 'file2.txt', 'file3.txt', 'file4.txt', 'file5.txt']
# --------------------------------------------------------------------------------

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
THRESHOLD = 0.4   # Adjust as needed

# --- Step 4: Single-Pass Clustering Algorithm ---
clusters = []
cluster_centroids = []

# %%
for i, doc_vector in enumerate(tfidf_matrix):
    assigned = False
    for j, centroid in enumerate(cluster_centroids):
        sim = cosine_similarity(doc_vector, centroid)[0][0]
        if sim >= THRESHOLD:
            clusters[j].append(filenames[i])
            # Update centroid (average of all vectors in cluster)
            cluster_centroids[j] = (cluster_centroids[j] + doc_vector) / 2
            assigned = True
            break

# %%
    if not assigned:
        clusters.append([filenames[i]])
        cluster_centroids.append(doc_vector)

# %%
print("Clusters formed:")
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")
# Out:
# Clusters formed:
# Cluster 1: ['file5.txt']

# %%
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")
# Out:
# Cluster 1: ['file5.txt']

# %%
# !pip install scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os

folder = r"C:\Users\vedik\OneDrive\Desktop\DCS_ISR\ISR_ASSIGNMENTS\Single pass\clustered_files"  # use your real path
documents = []
filenames = []

for file in os.listdir(folder):
    if file.endswith(".txt"):
        with open(os.path.join(folder, file), 'r', encoding='utf-8') as f:
            documents.append(f.read())
            filenames.append(file)

vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)

THRESHOLD = 0.1  # 🔼 stricter clustering
clusters = []
cluster_centroids = []

for i, doc_vector in enumerate(tfidf_matrix):
    assigned = False
    for j, centroid in enumerate(cluster_centroids):
        sim = cosine_similarity(doc_vector, centroid)[0][0]
        if sim >= THRESHOLD:
            clusters[j].append(filenames[i])
            cluster_centroids[j] = (cluster_centroids[j] + doc_vector) / 2
            assigned = True
            break
    if not assigned:
        clusters.append([filenames[i]])
        cluster_centroids.append(doc_vector)

print("\nClusters formed:")
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")
# Out:
# Requirement already satisfied: scikit-learn in c:\users\vedik\appdata\roaming\python\python312\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\vedik\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vedik\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vedik\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vedik\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
#
# Clusters formed:
# Cluster 1: ['file1.txt', 'file2.txt', 'file5.txt']
# Cluster 2: ['file3.txt', 'file4.txt']
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
