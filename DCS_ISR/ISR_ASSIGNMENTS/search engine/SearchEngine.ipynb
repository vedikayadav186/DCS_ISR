# %%
# !pip install beautifulsoup4 
import os
from bs4 import BeautifulSoup

folder = r"C:\Users\vedik\OneDrive\Desktop\DCS_ISR\ISR_ASSIGNMENTS\search engine\website"
index = {}

# Build index
for f in os.listdir(folder):
    if f.endswith(".html"):
        text = BeautifulSoup(open(os.path.join(folder, f), encoding="utf-8").read(), "html.parser").get_text().lower()
        for w in text.split():
            index.setdefault(w, set()).add(f)

# Search loop
while True:
    word = input("Search word (or 'exit'): ").lower()
    if word == "exit":
        break
    print("Found in:", ", ".join(index.get(word, [])) or "No page found")
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\vedik\appdata\roaming\python\python312\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vedik\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (2.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Search word (or 'exit'):  and
# Found in: contact.html, about.html, index.html, services.html
